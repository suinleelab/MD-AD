# %%
import h5py 
import numpy as np
from keras import optimizers, regularizers, losses
from keras.models import Model
from keras import backend as K
import keras
import sys
import pickle
import tensorflow as tf
import os
import pandas as pd

# %%
SPECIFIC_FOLDER= "origGE"
savepath = "../../md-ad_public_repo_data/Modeling/final_model/%s/model_transformations/"%SPECIFIC_FOLDER

# %%
os.listdir(savepath + "MTL/0")
# Out:
# ['97.txt',
#  '16.txt',
#  '100.txt',
#  '61.txt',
#  '3.txt',
#  '33.txt',
#  '27.txt',
#  '35.txt',
#  '0.txt',
#  '51.txt']

# %%
pd.read_csv("/media/big/nbbwang/AD_Project/analyses/MTL_variable_tasks/MTL_data/merged_phenotypes.csv", index_col=0)
# Out:
#        sample_name        filename  dementia  addx_to_death_cats  \
# 0        488395315         ACT.tsv       0.0                 0.0
# 1        496100277         ACT.tsv       0.0                 0.0
# 2        496100278         ACT.tsv       0.0                 0.0
# 3        496100279         ACT.tsv       0.0                 0.0
# 4        496100281         ACT.tsv       1.0                 2.0
# 5        496100283         ACT.tsv       1.0                 2.0
# 6        496100284         ACT.tsv       1.0                 2.0
# 7        496100285         ACT.tsv       1.0                 2.0
# 8        496100287         ACT.tsv       0.0                 0.0
# 9        496100288         ACT.tsv       0.0                 0.0
# 10       496100290         ACT.tsv       0.0                 0.0
# 11       496100291         ACT.tsv       0.0                 0.0
# 12       496100292         ACT.tsv       0.0                 0.0
# ...
