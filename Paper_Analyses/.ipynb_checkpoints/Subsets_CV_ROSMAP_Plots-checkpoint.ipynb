# %%
# PACKAGES
import matplotlib.pyplot as plt
import itertools
import numpy as np
import os
import scipy
import pandas as pd
# %matplotlib inline
import seaborn as  sns
from itertools import chain, combinations

# %%
dset = "R"

path_to_subsets_CV_results = {"A": "../../Pipeline_Outputs_Submitted/origGE/results/MTL/act_test_set.csv",
                              "M": "../../Pipeline_Outputs_Submitted/origGE/results/MTL/msbb_test_set.csv",
                              "R": "../../Pipeline_Outputs_Submitted/origGE/results/MTL/ROSMAP_CV_subsets_results.csv"}

# %%
cmap=plt.cm.tab20
cmaplist = [cmap(i) for i in range(cmap.N)]
light_phenotype_colors = {"CERAD": cmaplist[3], "PLAQUES": cmaplist[7],  "ABETA_IHC": cmaplist[11], 
                    "BRAAK": cmaplist[5], "TANGLES": cmaplist[1], "TAU_IHC": cmaplist[9]}

phenotype_colors = {"CERAD": cmaplist[2], "PLAQUES": cmaplist[6],  "ABETA_IHC": cmaplist[10], 
                    "BRAAK": cmaplist[4], "TANGLES": cmaplist[0], "TAU_IHC": cmaplist[8]}

# %%
df= pd.read_csv(path_to_subsets_CV_results[dset])
df = df.drop("Fold",axis=1).replace(0, np.nan)

# %%
dset_avail = {"A": np.array(["CERAD", "ABETA_IHC", "BRAAK", "TAU_IHC"]), 
             "M": np.array(["CERAD", "PLAQUES", "BRAAK"]),
             "R": np.array(["CERAD", "PLAQUES",  "ABETA_IHC", "BRAAK", "TANGLES", "TAU_IHC"])}

# %%
# M should actually be 879, but its the same as A+R, so i changed it for plotting purposes
dset_sizes = {"A": 337, "M": 870, "R": 550}
actual_dset_sizes = {"A": 337, "M": 879, "R": 542}

# %%
def powerset(iterable):
    s = list(iterable)
    return list(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))[1:]


subset_sizes = {}
subset_variables = {}

for subset in list(powerset(dset_sizes.keys())):
    subset_name = "".join(subset)
    subset_variables[subset_name] = np.array([])
    subset_sizes[subset_name] = 0
    for elt in subset:
        subset_variables[subset_name] = np.union1d(subset_variables[subset_name], dset_avail[elt])
        subset_sizes[subset_name] += dset_sizes[elt]

# %%
grouped_means = df.groupby(['Phenotype', "Subset"]).mean()
means = pd.DataFrame(grouped_means.to_records(), columns=["Phenotype", "Subset", "Val"])

grouped_sems = df.groupby(['Phenotype', 'Subset']).sem()
sems = pd.DataFrame(grouped_sems.to_records(), columns=["Phenotype", "Subset", "Val"])

# %%
means["Sizes"] = means["Subset"].apply(lambda x: subset_sizes[x])
means["Colors"] = means["Phenotype"].apply(lambda x: phenotype_colors[x])
means["Light_Colors"] = means["Phenotype"].apply(lambda x: light_phenotype_colors[x])

# means["Shape"] = means["Subset"].apply(lambda x: "D" if "R" in x else "o")
means["Shape"] = means["Subset"].apply(lambda x: "D" if dset in x else "o")

# %%
means_1 = means[means["Phenotype"].isin(["CERAD", "PLAQUES", "ABETA_IHC"])]
means_2 = means[means["Phenotype"].isin(["BRAAK", "TANGLES", "TAU_IHC"])]

# %%
def get_num_labels(row):
    dsets_w_phen = np.array([k for k in dset_avail.keys() if row["Phenotype"] in dset_avail[k]])
    training_dsets_w_phen = np.intersect1d(list(row["Subset"]), dsets_w_phen)
    num_labels = 0
    for dset in training_dsets_w_phen:
        num_labels += dset_sizes[dset]
    return num_labels

means_1["num_labels"] = 0
for i,row in means_1.iterrows():
    means_1.loc[i, "num_labels"] = get_num_labels(row)

means_2["num_labels"] = 0 
for i,row in means_2.iterrows():
    means_2.loc[i, "num_labels"] = get_num_labels(row)

    
means_1["Light_Colors"] = "#cccccc"
means_2["Light_Colors"] = "#cccccc"
# Out:
# /homes/gws/nbbwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /homes/gws/nbbwang/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /homes/gws/nbbwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /homes/gws/nbbwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /homes/gws/nbbwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
f,axs = plt.subplots(2,1, figsize=(5,10), sharey=True)
for ax_id,toplot in enumerate([means_1, means_2]):

    for x in toplot["Sizes"].unique():
        axs[ax_id].axvline(x, alpha=.3, color="gray")
        
    for i,subdf in toplot.groupby(["Phenotype", "Shape"]):
        temp = subdf.sort_values("Sizes")
        temp = temp.dropna()
        if subdf["Shape"].values[0] == "o":
            ls = "--"
        else: 
            ls = "-"
            
        if len(temp)>0:
            axs[ax_id].plot(temp["Sizes"], temp["Val"], c=temp["Colors"].values[0], alpha=.3, ls=ls)
    
    for markertype in toplot["Shape"].unique():
        subdf = toplot[toplot["Shape"]==markertype]
        axs[ax_id].scatter(subdf["Sizes"], subdf["Val"], c=subdf["Light_Colors"], marker=markertype, s=subdf["Sizes"]/5, alpha=.9)#, edgecolors=subdf["Colors"])
        axs[ax_id].scatter(subdf["Sizes"], subdf["Val"], c=subdf["Colors"], marker=markertype, s=subdf["num_labels"]/5, alpha=.9)

    axs[ax_id].spines['right'].set_visible(False)
    axs[ax_id].spines['top'].set_visible(False)
    axs[ax_id].xaxis.set_major_locator(plt.MaxNLocator(4))
    axs[ax_id].set_facecolor("None")

# %% [markdown]
# ## Sourcedata

# %%
sourcedata= pd.read_csv(path_to_subsets_CV_results[dset])
sourcedata = sourcedata.replace(0, np.nan)
sourcedata["Fold"] = sourcedata["Fold"] - 24
sourcedata.to_csv("sourcedata/2b_cv_%s_subsets.csv"%dset, index=False)

# %% [markdown]
# ## Revision 2: Fractional MSBB transfer experiments
# Addition from 2nd revision:
# - Train on all of ROSMAP + fractions of MSBB & evaluate on ACT
# - (Also: Train on all of ACT + fractions of MSBB & evaluate on ROSMAP)

# %%
path_to_subsets_CV_fractional_results = {"A": "../../Pipeline_Outputs_Submitted/origGE/results/MTL/fractional_test_act.csv",
                              "R": "../../Pipeline_Outputs_Submitted/origGE/results/MTL/fractional_test_rosmap.csv"}

# %%
dset = "R"

# %%
df= pd.read_csv(path_to_subsets_CV_results[dset])
if dset=="A":
    tmp = df[df["Subset"]=="R"]
    tr_dsets = ["M", "R"]
elif dset=="R":
    tmp = df[df["Subset"]=="A"]
    tr_dsets = ["A", "M"]

tmp["Frac"]=0
tmp = tmp[["Val", "Phenotype", "Fold", "Frac"]]
# Out:
# /homes/gws/nbbwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df= pd.read_csv(path_to_subsets_CV_fractional_results[dset])
df = pd.concat([tmp, df])
df = df.drop("Fold",axis=1)
df["Val"] = df["Val"].replace(0, np.nan)

available_training_phens = np.unique(np.hstack(np.array([dset_avail[x] for x in tr_dsets]).flatten()))
df.loc[list(df[~df["Phenotype"].isin(available_training_phens)].index), "Val"] = np.nan

# %%
def get_fractional_markersize(testdset, phenotype, frac):
    train_base_dset = np.setdiff1d(["A", "M", "R"], ["M", testdset])[0]
    base_size = float(phenotype in dset_avail[train_base_dset])
    MSBB_size = float(phenotype in dset_avail["M"]) * frac * 2
    
    if base_size + MSBB_size == 0:
        unlabeled_size = 0
    else:
        unlabeled_size = 1 + frac * 2
    return (base_size + MSBB_size), unlabeled_size

# %%
train_base_dset = np.setdiff1d(["A", "M", "R"], ["M", dset])[0]

# %%
[actual_dset_sizes[train_base_dset] + x * actual_dset_sizes["M"] for x in [0,.25,.5,.75,1]]
# Out:
# [337, 556.75, 776.5, 996.25, 1216]

# %%
grouped_means = df.groupby(['Phenotype', "Frac"]).mean()
means = pd.DataFrame(grouped_means.to_records(), columns=["Phenotype", "Frac", "Val"])

grouped_sems = df.groupby(['Phenotype', 'Frac']).sem()
sems = pd.DataFrame(grouped_sems.to_records(), columns=["Phenotype", "Frac", "Val"])



means["labeled_size"]=0
means["all_size"]=0

for i,row in means.iterrows():
    labsize, allsize = get_fractional_markersize(dset, row["Phenotype"], row["Frac"])
    means.loc[i,"labeled_size"] = labsize
    means.loc[i,"all_size"] = allsize
    
means["color"] = means["Phenotype"].apply(lambda x: phenotype_colors[x])
    
means_1 = means[means["Phenotype"].isin(["CERAD", "PLAQUES", "ABETA_IHC"])]
means_2 = means[means["Phenotype"].isin(["BRAAK", "TANGLES", "TAU_IHC"])]

# %%
f,axs = plt.subplots(2,1, figsize=(5,10), sharey=True)


for ax_id,toplot in enumerate([means_1, means_2]):
    
    for i,subdf in toplot.groupby(["Phenotype"]):
        temp = subdf.sort_values("Frac")
        temp = temp.dropna()    
        if len(temp)>0:
            axs[ax_id].plot(temp["Frac"], temp["Val"], c=temp["color"].values[0], alpha=.3, ls="--")
    
    axs[ax_id].scatter(toplot["Frac"], toplot["Val"], c="#cccccc", s=toplot["all_size"]*200, alpha=1)#, edgecolors=subdf["Colors"])
    axs[ax_id].scatter(toplot["Frac"], toplot["Val"], c=toplot["color"], s=toplot["labeled_size"]*200, alpha=1)#, edgecolors=subdf["Colors"])

    axs[ax_id].spines['right'].set_visible(False)
    axs[ax_id].spines['top'].set_visible(False)
    axs[ax_id].xaxis.set_major_locator(plt.MaxNLocator(5))
    axs[ax_id].set_facecolor("None")
